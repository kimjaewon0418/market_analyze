# %%
import pandas as pd

# %%
df = pd.read_csv('/content/소상공인시장진흥공단_전통시장 경기동향(BSI) 현황_20230730.CSV',encoding='cp949')

# %%
df
# Out:
#        연도  월  경기전반체감  경기전반전망  매출체감   매출전망  자금사정체감  자금사정전망  비용상황체감  비용상황전망  \
# 0    2013  1    42.2    70.7  41.4   87.5    48.8    70.4     NaN     NaN
# 1    2013  2    50.2    82.6  50.6   87.5    54.2    92.8     NaN     NaN
# 2    2013  3    55.0    97.3  53.4  103.0    55.5    87.6     NaN     NaN
# 3    2013  4    61.7   100.3  61.1  105.8    59.4    88.5     NaN     NaN
# 4    2013  5    65.5    93.8  68.4   99.5    62.6    86.4     NaN     NaN
# ..    ... ..     ...     ...   ...    ...     ...     ...     ...     ...
# 123  2023  4    56.9    84.5  53.8   80.8    57.1    78.8    98.9    99.8
# 124  2023  5    63.2    79.8  60.6   77.0    63.3    76.6   110.2    99.4
# 125  2023  6    50.9    70.0  47.8   68.2    53.0    69.4    99.4   106.4
# 126  2023  7    40.7    56.5  38.1   52.4    45.7    58.1    98.9   100.6
# 127  2023  8     NaN    62.0   NaN   53.4     NaN    57.2     NaN    97.5
#
#      ...  전북체감  전북전망  전남체감  전남전망  경북체감  경북전망  경남체감  경남전망  제주체감  제주전망
# ...

# %%
df.tail(10)
# Out:
#        연도   월  경기전반체감  경기전반전망  매출체감  매출전망  자금사정체감  자금사정전망  비용상황체감  비용상황전망  \
# 118  2022  11    58.0    83.5  58.1  83.2    62.2    80.7   109.8   110.2
# 119  2022  12    54.0    78.5  53.1  77.5    58.8    79.2   106.8   104.0
# 120  2023   1    60.0    86.5  55.5  86.5    55.9    83.5   108.2   105.5
# 121  2023   2    41.4    59.3  37.0  54.8    48.6    61.1   113.2    92.9
# 122  2023   3    59.7    89.2  53.7  85.2    57.5    82.5   101.1   104.7
# 123  2023   4    56.9    84.5  53.8  80.8    57.1    78.8    98.9    99.8
# 124  2023   5    63.2    79.8  60.6  77.0    63.3    76.6   110.2    99.4
# 125  2023   6    50.9    70.0  47.8  68.2    53.0    69.4    99.4   106.4
# 126  2023   7    40.7    56.5  38.1  52.4    45.7    58.1    98.9   100.6
# 127  2023   8     NaN    62.0   NaN  53.4     NaN    57.2     NaN    97.5
#
#      ...  전북체감   전북전망  전남체감  전남전망  경북체감  경북전망  경남체감  경남전망  제주체감  제주전망
# 118  ...  66.4  101.6  48.2  88.2  58.2  79.8  60.0  80.5  50.0  75.5
# ...

# %%
df.describe()
# Out:
#                 연도           월      경기전반체감      경기전반전망        매출체감  \
# count   128.000000  128.000000  127.000000  128.000000  127.000000
# 121  29.2  58.6  38.2  57.6  45.5  61.1  34.8  54.3  49.0  67.6
# 122  65.0  86.7  63.8  87.5  66.0  91.0  64.3  86.2  66.3  93.9
# ...

# %%
af.loc[:,['경기전반체감','경기전반전망']]
# Out:
#      경기전반체감  경기전반전망
# 120    60.0    86.5
# 121    41.4    59.3
# 122    59.7    89.2
# 123    56.9    84.5
# 124    63.2    79.8
# 125    50.9    70.0
# 126    40.7    56.5
# 127     NaN    62.0

# %%
df
# Out:
#        연도  월  경기전반체감  경기전반전망  매출체감   매출전망  자금사정체감  자금사정전망  비용상황체감  비용상황전망  \
# 0    2013  1    42.2    70.7  41.4   87.5    48.8    70.4     NaN     NaN
# 1    2013  2    50.2    82.6  50.6   87.5    54.2    92.8     NaN     NaN
# 2    2013  3    55.0    97.3  53.4  103.0    55.5    87.6     NaN     NaN
# 3    2013  4    61.7   100.3  61.1  105.8    59.4    88.5     NaN     NaN
# 4    2013  5    65.5    93.8  68.4   99.5    62.6    86.4     NaN     NaN
# ..    ... ..     ...     ...   ...    ...     ...     ...     ...     ...
# 123  2023  4    56.9    84.5  53.8   80.8    57.1    78.8    98.9    99.8
# 124  2023  5    63.2    79.8  60.6   77.0    63.3    76.6   110.2    99.4
# 125  2023  6    50.9    70.0  47.8   68.2    53.0    69.4    99.4   106.4
# 126  2023  7    40.7    56.5  38.1   52.4    45.7    58.1    98.9   100.6
# 127  2023  8     NaN    62.0   NaN   53.4     NaN    57.2     NaN    97.5
#
#      ...  전북체감  전북전망  전남체감  전남전망  경북체감  경북전망  경남체감  경남전망  제주체감  제주전망
# ...

# %%
df.groupby(['연도','월'])['경기전반체감'].sum().plot.line()
# Out:
# <Axes: xlabel='연도,월'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df.groupby(['연도','월'])['경기전반전망'].sum().plot.line()
# Out:
# <Axes: xlabel='연도,월'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# 그래프를 봤을 때 연도, 월별 경기전반체감과 전망을 비교해 봤을 때 최솟값과 최대값 기준값이 다르고 체감은 낮고 전망은 높은것을 확인할 수 있었다.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
plt.plot(df["경기전반체감"], label="BSI")
plt.plot(df["경기전반전망"], label="KDI")
plt.legend(fontsize=16)

plt.show()

# %%
df.groupby(['연도','월'])['매출체감'].sum().plot.line()
# Out:
# <Axes: xlabel='연도,월'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df.groupby(['연도','월'])['매출전망'].sum().plot.line()
# Out:
# <Axes: xlabel='연도,월'>
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# 위와 같이 연도, 월별 경기전반체감과 전망을 비교해 봤을 때 최솟값과 최대값 기준값이 다르고 체감은 낮고 전망은 높은것을 확인할 수 있었다.

# %%
af.pivot_table(index = ['연도','월'], columns = '구매고객수체감', aggfunc = 'sum')
